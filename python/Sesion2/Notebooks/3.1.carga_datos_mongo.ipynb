# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd
from pymongo import MongoClient
from datetime import datetime

# %%
engine = db.create_engine("mysql://root:root@192.168.18.6:3310/db_movies_netflix_transact")
conn = engine.connect()

# %%
movie_df = pd.read_sql_query(text('SELECT * FROM movie'), con=conn)
movie_df
# Out:
#     movieID       movieTitle releaseDate originalLanguage  \
# 0  80192187  Triple Frontier  2019-04-12          English
# 1  80210920       The Mother  2023-01-05          English
# 2  81157374              Run  2021-05-21          English
#
#                                            link
# 0  https://www.netflix.com/pe-en/title/80192187
# 1  https://www.netflix.com/pe-en/title/80210920
# 2  https://www.netflix.com/pe-en/title/81157374

# %%
def get_database():

    CONNECTION_STRING = "mongodb+srv://m001-student:Bd8trinRHEJbV4a2@sandbox.okkbl.mongodb.net/?retryWrites=true&w=majority"
    client = MongoClient(CONNECTION_STRING)

    return client['netflix_db']

# %%
df = movie_df.copy()
df.reset_index(inplace=False)
df['releaseDate'] = pd.to_datetime(df['releaseDate'])
df_to_dict = df.to_dict("records")
dbname = get_database()
dbname["movies"].insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('65da1e0703920c8aff20d572'), ObjectId('65da1e0703920c8aff20d573'), ObjectId('65da1e0703920c8aff20d574')], acknowledged=True)

# %%
def get_database():

    CONNECTION_STRING = "mongodb+srv://m001-student:Bd8trinRHEJbV4a2@sandbox.okkbl.mongodb.net/?retryWrites=true&w=majority"
    #mongodb+srv://m001-student:@sandbox.okkbl.mongodb.net/?retryWrites=true&w=majority
    client = MongoClient(CONNECTION_STRING)

    return client['retail_db']

# %%
infile = './data_retail/customers'
df_customer = pd.read_csv(infile,sep='|', header=None, names=["customer_id","customer_fname","customer_lname","customer_email","customer_password","customer_street","customer_city","customer_state","customer_zipcode"])

# %%
df = df_customer.copy()
df.reset_index(inplace=False)
df_to_dict = df.to_dict("records")
dbname = get_database()
dbname["customers"].insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('65da1e4f03920c8aff20d576'), ObjectId('65da1e4f03920c8aff20d577'), ObjectId('65da1e4f03920c8aff20d578'), ObjectId('65da1e4f03920c8aff20d579'), ObjectId('65da1e4f03920c8aff20d57a'), ObjectId('65da1e4f03920c8aff20d57b'), ObjectId('65da1e4f03920c8aff20d57c'), ObjectId('65da1e4f03920c8aff20d57d'), ObjectId('65da1e4f03920c8aff20d57e'), ObjectId('65da1e4f03920c8aff20d57f'), ObjectId('65da1e4f03920c8aff20d580'), ObjectId('65da1e4f03920c8aff20d581'), ObjectId('65da1e4f03920c8aff20d582'), ObjectId('65da1e4f03920c8aff20d583'), ObjectId('65da1e4f03920c8aff20d584'), ObjectId('65da1e4f03920c8aff20d585'), ObjectId('65da1e4f03920c8aff20d586'), ObjectId('65da1e4f03920c8aff20d587'), ObjectId('65da1e4f03920c8aff20d588'), ObjectId('65da1e4f03920c8aff20d589'), ObjectId('65da1e4f03920c8aff20d58a'), ObjectId('65da1e4f03920c8aff20d58b'), ObjectId('65da1e4f03920c8aff20d58c'), ObjectId('65da1e4f03920c8aff20d58d'), ObjectId('65da1e4f03920c8aff20d58e'), ObjectId('65da1e4f03920c8aff20d58f'), ObjectId('65da1e4f03920c8aff20d590'), ObjectId('65da1e4f03920c8aff20d591'), ObjectId('65da1e4f03920c8aff20d592'), ObjectId('65da1e4f03920c8aff20d593'), ObjectId('65da1e4f03920c8aff20d594'), ObjectId('65da1e4f03920c8aff20d595'), ObjectId('65da1e4f03920c8aff20d596'), ObjectId('65da1e4f03920c8aff20d597'